# %% [markdown]
# Hardware: The physical parts of a computer that you can see and touch.
# Example: Monitor
#
# Software: The programs or applications that run on a computer and control what it does.
# Example: Microsoft Word
